# %%
import sys, os
sys.path.append("/cluster/home/vogtva/pde-data-gen")

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from src.db_tools import make_animation

# %%
ds = xr.open_dataset('/cluster/scratch/vogtva/data/bruss/param_sweep/_dataset.nc')

# %%
idx = np.random.randint(0, 10800)
idx
# Out:
# 798

# %%
d = ds['data'][idx]
# make_animation(d, str(idx), ".")
d = d[:, :, 0::2]

# %%
fig, ax = plt.subplots(1,1)
ax.imshow(d[20])
plt.show()
